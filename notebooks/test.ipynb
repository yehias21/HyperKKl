# %% [markdown]
# # Dataset visualization

# %%
# imports 
import matplotlib.pyplot as plt

# %%
file_path = '../data/Duffing/2024-01-30/02-23-24/input.pkl'
import pickle
with open(file_path, 'rb') as f:
    input = pickle.load(f)
import numpy as np
print(input.shape)
# Out:
# (5, 1000)

# %%
# plot using scatter plot
inst = input[0]
print(inst.shape)
plt.scatter(np.arange(len(inst))[:100], inst[:100])
# Out:
# (1000,)

# %%
np.arange(len(inst))[1]
# Out:
# 1
